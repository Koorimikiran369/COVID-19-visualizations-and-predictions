# %%
#!pip install selenium pandas

# %%
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup 
import requests

# %%
data = requests.get('https://www.covid19india.org/','lsml')
data
# Out:
# <Response [200]>

# %%
data.text
# Out:
# '<!doctype html><html lang="en"><head><meta charset="utf-8"/><link rel="icon" href="/favicon.ico"/><meta name="viewport" content="width=device-width,initial-scale=1"/><meta name="theme-color" content="#000000"/><link rel="apple-touch-icon" href="/logo192.png"/><link rel="manifest" href="/manifest.json"/><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"><link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png"><link rel="manifest" href="/site.webmanifest"><title>COVID-19 Tracker | India</title><meta name="title" content="COVID-19 Tracker | India"><meta name="description" content="Volunteer-driven crowdsourced initiative to track the spread of Coronavirus (COVID-19) in India"><meta name="keywords" content="coronavirus,corona,covid,covid19,covid-19,covidindia,india,virus"><meta property="og:type" content="website"><meta property="og:url" content="https://www.covid19india.org
# ...

# %%
data_soup = BeautifulSoup(data.text)
data_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(data_soup.title.text)
# Out:
# COVID-19 Tracker | India

# %%
data_tag = data_soup.find_all('tbody')
data_tag
# Out:
# []

# %%
Country_Name = []
Confirmed = []
Cases_per_1M_people = []
Recovered = []
Death = []

# %%
for i in data_tag:
    a = i.text
    print(a)
# Out:
# Worldwide
# 629,627
# 89.35
# 138,087
# 28,967
# United States
# 115,976
# 354.57
# 3,219
# 1,935
# Italy
# 92,472
# 1,463.97
# 12,384
# 10,023
# China
# 81,394
# 59.27
# 74,971
# 3,295
# Spain
# 72,248
# 1,458.07
# 12,285
# 5,694
# Germany
# 55,570
# 676.55
# 4,107
# 420
# Iran
# 35,408
# 437.18
# 11,679
# 2,517
# France
# 32,964
# 487.88
# 5,700
# 1,995
# United Kingdom
# 17,089
# 263.34
# 140
# 1,028
# Switzerland
# 13,795
# 2,033.16
# 1,524
# 255
# Netherlands
# 9,806
# 602.18
# 0
# 640
# South Korea
# 9,478
# 185.7
# 4,811
# 144
# Belgium
# 9,134
# 886.18
# 1,063
# 353
# Austria
# 8,105
# 1,034.33
# 225
# 68
# Turkey
# 5,698
# 68.07
# 42
# 92
# Portugal
# 5,170
# 484.23
# 43
# 100
# Canada
# 4,735
# 137.04
# 353
# 55
# Norway
# 3,973
# 745.56
# 0
# 22
# Australia
# 3,636
# 158.85
# 224
# 14
# Brazil
# 3,477
# 16.87
# 6
# 93
# Israel
# 3,460
# 303.42
# 89
# 12
# Sweden
# 3,460
# 344.21
# 18
# 110
# Czechia
# 2,541
# 238.6
# 11
# 9
# Denmark
# 2,366
# 426.38
# 0
# 65
# Malaysia
# ...

# %%
for i in data_tag:
    a = i.text
    #print(a)
    name = re.search(r'^[a-zA-Z]+(\s[a-zA-Z]+)?$',a)
    if name:
        Country_Name.append(name.group())
        
Country_Name
# Out:
# ['Worldwide',
#  'United States',
#  'Italy',
#  'China',
#  'Spain',
#  'Germany',
#  'Iran',
#  'France',
#  'United Kingdom',
#  'Switzerland',
#  'Netherlands',
#  'South Korea',
#  'Belgium',
#  'Austria',
#  'Turkey',
#  'Portugal',
#  'Canada',
#  'Norway',
#  'Australia',
#  'Brazil',
#  'Israel',
#  'Sweden',
#  'Czechia',
#  'Denmark',
#  'Malaysia',
#  'Ireland',
#  'Chile',
#  'Ecuador',
#  'Luxembourg',
#  'Japan',
#  'Poland',
#  'Romania',
#  'Pakistan',
#  'Russia',
#  'Thailand',
#  'Saudi Arabia',
#  'South Africa',
#  'Finland',
#  'Indonesia',
#  'Philippines',
#  'Greece',
#  'India',
#  'Iceland',
#  'Singapore',
#  'Panama',
#  'Dominican Republic',
#  'Mexico',
#  'Argentina',
#  'Slovenia',
#  'Serbia',
#  'Croatia',
#  'Estonia',
#  'Peru',
#  'Qatar',
#  'Hong Kong',
#  'Colombia',
#  'Egypt',
#  'Iraq',
#  'Bahrain',
#  'Algeria',
#  'New Zealand',
#  'Lebanon',
#  'Lithuania',
#  'Armenia',
#  'Morocco',
#  'Hungary',
#  'Bulgaria',
#  'Ukraine',
# ...

# %%
for i in data_tag:
    a = i.text
    
    confirm = re.search(r'^[0-999999]$',a)
    if name:
        Confirmed.append(confirm.group())
        
Confirmed
# Out:
# []

# %%
Total_confirmed = []
for item in gdp_table_data:
    match = re.findall(r'\d+[(,)]\d+',item.text)
    if match:
        Total_confirmed.append((match))

# %%
Total_confirmed
# Out:
# [['104,256', '2,525', '1,704'],
#  ['86,498', '10,950', '9,134'],
#  ['81,394', '74,971', '3,295'],
#  ['65,719', '9,357', '5,138'],
#  ['53,340', '6,658'],
#  ['35,408', '11,679', '2,517'],
#  ['32,964', '5,700', '1,995'],
#  ['14,543'],
#  ['13,187', '1,530'],
#  ['9,478', '4,811'],
#  ['8,603'],
#  ['7,712'],
#  ['7,284'],
#  ['5,698'],
#  ['4,757'],
#  ['4,268'],
#  ['3,794'],
#  ['3,635'],
#  ['3,477'],
#  ['3,460'],
#  ['3,069'],
#  ['2,422'],
#  ['2,320'],
#  ['2,121'],
#  ['2,046'],
#  ['1,627'],
#  ['1,610'],
#  ['1,605'],
#  ['1,499'],
#  ['1,436'],
#  ['1,408'],
#  ['1,292'],
#  ['1,264'],
#  ['1,245'],
#  ['1,170'],
#  ['1,165'],
#  ['1,155'],
#  ['1,104'],
#  ['1,075']]

# %%
data = {}
for table in gdp_table_data.findAll("table"):
    # Get headers of table i.e., Rank, Country, GDP.
    t_headers = []
    for th in table.find_all("th"):
        # remove any newlines and extra spaces from left and right
        t_headers.append(th.text.replace('\n', ' ').strip())
    # Get all the rows of table
    table_data = []
    for tr in table.tbody.find_all("tr"): # find all tr's from table's tbody
        t_row = {}
        # Each table row is stored in the form of
        # t_row = {'Rank': '', 'Country/Territory': '', 'GDP(US$million)': ''}

        # find all td's(3) in tr and zip it with t_header
        for td, th in zip(tr.find_all("td"), t_headers): 
            t_row[th] = td.text.replace('\n', '').strip()
        table_data.append(t_row)

    # Put the data for the table with his heading.
    #data[heading] = table_data

print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-453c7d3dd04c> in <module>
#       1 data = {}
# ----> 2 for table in gdp_table_data.findAll("table"):
#       3     # Get headers of table i.e., Rank, Country, GDP.
#       4     t_headers = []
#       5     for th in table.find_all("th"):
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'findAll'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
headings = []
for td in gdp_table_data[0].find_all("div"):
    # remove any newlines and extra spaces from left and right
    headings.append(td.b.text.replace('\n', ' ').strip())

print(headings)
# Out:
# []

# %%
elements = soup.select('div',class_ = 'textwidget custom-html-widget')
#My_table = soup.find('table',class_ = 'table-auto w-full')
#My_table

# %%
secondary_elements = soup.select('table',class_='list_table_subs')
secondary_elements
# Out:
# [<table class="table-auto w-full" data-v-4497c0a8=""><thead class="text-xs leading-tight border-b-2" data-v-4497c0a8=""><tr data-v-4497c0a8=""><th class="border px-2 py-2" data-v-4497c0a8="">Country</th> <th class="border px-1 py-2" data-v-4497c0a8="">Total Confirmed</th> <th class="border px-1 py-2" data-v-4497c0a8="">Total Recovered</th> <th class="border px-1 py-2" data-v-4497c0a8="">Total Deaths</th></tr></thead> <tbody class="font-bold" data-v-4497c0a8=""><tr data-v-4497c0a8=""><td class="bg-gray-200 text-xs border px-2 py-2 hover:bg-primary hover:text-white" data-v-4497c0a8=""><a class="" data-v-4497c0a8="" href="/country/us" style="display: block;"><i class="flag-icon flag-icon-us" data-v-4497c0a8=""></i>
#                USA
# ...

# %%
Furnishing = []
furnish = soup.find('div',class_='textwidget custom-html-widget')
for item in furnish:
        if furnish:
            Furnishing.append(item.text)

# %%
Furnishing
# Out:
# ['\n\n\n\n\r\n     (adsbygoogle = window.adsbygoogle || []).push({});\r\n\n\n\n\nWorld COVID-19 TrackerCoronavirus TrackerLast Updated45 Minutes AgoConfirmed[+3592]597,267 Active[+2643]434,039Recovered[+777]133,667 Deceased[+172]27,382\nSave My World, Please Share this!\n\n\n\n\n\n\r\n     (adsbygoogle = window.adsbygoogle || []).push({});\r\n\n ',
#  'World Map\n',
# ...
